# %%
import numpy as np
import seaborn as sns; sns.set()
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [15, 10]

font = {'size'   : 20, }
axes = {'labelsize': 'large', 'titlesize': 'large'}

mpl.rc('font', **font)
mpl.rc('axes', **axes)

import pandas as pd
import data_utils
import matplotlib.style as style

# %%
# Paths to data csvs
wd = "/home/behzad/Documents/barnes_lab/cplusplus_software/speed_test/repressilator/cpp"
data_dir = wd + "/output/two_species_stable_6/Population_0"
distances_path = data_dir + "/distances.csv"
eigenvalues_path = data_dir + "/eigenvalues_do_fsolve_state.csv"
model_space_report_path = data_dir + "/model_space_report.csv"
adj_mat_dir = "/home/behzad/Documents/barnes_lab/sympy_consortium_framework/output/two_species_no_symm/adj_matricies/model_#REF#_adj_mat.csv"
output_dir = wd + "/data_analysis_notebook/figures/figure_3_parts/"

# %%
# Load dataframes
distances_df = pd.read_csv(distances_path)
eigenvalues_df = pd.read_csv(eigenvalues_path)
model_space_report_df = pd.read_csv(model_space_report_path)

# Make distances numeric
distances_df = data_utils.distances_pre_processing(distances_df)

# %%
# Join eigenvalues and distances on the simulation index, batch number and model_ref

all_neg_eig = data_utils.all_negative_eigs(eigenvalues_df)
all_real_eig = data_utils.all_real_eigs(eigenvalues_df)
all_zero_eig = data_utils.all_zero_eigs(eigenvalues_df)

eigenvalues_df['all_neg_eig'] = all_neg_eig
eigenvalues_df['all_real_eig'] = all_real_eig
eigenvalues_df['all_zero_eig'] = all_zero_eig

positive_loops, negative_loops = data_utils.make_feedback_loop_counts(model_space_report_df, adj_mat_dir)
total_num_parts, num_AHL_parts, num_microcin_parts = data_utils.make_num_parts(model_space_report_df, 
                                                                               adj_mat_dir)
model_space_report_df['pos_loop_count'] = positive_loops
model_space_report_df['neg_loop_count'] = negative_loops
model_space_report_df['total_num_parts'] = total_num_parts

loop_ratios = []
for x, y in zip(negative_loops, positive_loops):
    try:
        loop_ratios.append(x/y)
    
    except(ZeroDivisionError):
        loop_ratios.append(np.nan)
        
    
model_space_report_df['loop_count_ratio'] = loop_ratios
# Out:
# Index(['eig_0_real', 'eig_1_real', 'eig_2_real', 'eig_3_real', 'eig_4_real',
#        'eig_5_real', 'eig_6_real', 'eig_7_real', 'eig_8_real', 'eig_9_real'],
#       dtype='object')

# %%
joint_df = pd.merge(left=eigenvalues_df, right=distances_df, how='inner', on=['sim_idx', 'batch_num', 'model_ref'])
joint_df.reset_index()

# joint_df['sum_std'] = joint_df['d2'] + joint_df['d5']
# # Set accepted or rejected particles
# mask = (joint_df['d1'] == 0) & (joint_df['d2'] < 100) & (joint_df['d3'] > 1e4) & (joint_df['d4'] == 0) & (joint_df['d5'] < 100) & (joint_df['d6'] > 1e4)
# joint_df.loc[mask, 'Accepted'] = True
# joint_df.loc[~mask, 'Accepted'] = False
# Out:
#            index  sim_idx  batch_num  model_ref      integ_error  \
# 0              0        0          0        114  species_decayed
# 1              1        1          0          2  species_decayed
# 2              2        2          0        100              NaN
# 3              3        3          0          1              NaN
# 4              4        4          0         81  species_decayed
# 5              5        5          0          7              NaN
# 6              6        6          0         83  species_decayed
# 7              7        7          0        102  species_decayed
# 8              8        8          0         11  species_decayed
# 9              9        9          0         26  species_decayed
# 10            10       10          0         77              NaN
# 11            11       11          0        123  species_decayed
# 12            12       12          0        124  species_decayed
# 13            13       13          0         99  species_decayed
# 14            14       14          0         16  species_decayed
# 15            15       15          0         82  species_decayed
# 16            16       16          0          1              NaN
# 17            17       17          0        126  species_decayed
# 18            18       18          0         82  species_decayed
# 19            19       19          0        109              NaN
# 20            20       20          0          9              NaN
# 21            21       21          0         56  species_decayed
# 22            22       22          0        102  species_decayed
# 23            23       23          0         74  species_decayed
# 24            24       24          0          0              NaN
# 25            25       25          0         32  species_decayed
# 26            26       26          0         15              NaN
# 27            27       27          0          4              NaN
# 28            28       28          0         96  species_decayed
# 29            29       29          0         27              NaN
# ...          ...      ...        ...        ...              ...
# 1993470  1993470      270       6644        102  species_decayed
# 1993471  1993471      271       6644        113  species_decayed
# 1993472  1993472      272       6644         19  species_decayed
# 1993473  1993473      273       6644        108              NaN
# 1993474  1993474      274       6644         93              NaN
# 1993475  1993475      275       6644        122              NaN
# 1993476  1993476      276       6644         87  species_decayed
# 1993477  1993477      277       6644         85  species_decayed
# 1993478  1993478      278       6644        119  species_decayed
# 1993479  1993479      279       6644         82  species_decayed
# 1993480  1993480      280       6644         70  species_decayed
# 1993481  1993481      281       6644         59  species_decayed
# 1993482  1993482      282       6644          2              NaN
# 1993483  1993483      283       6644         15              NaN
# 1993484  1993484      284       6644         74  species_decayed
# 1993485  1993485      285       6644        108  species_decayed
# 1993486  1993486      286       6644         86  species_decayed
# 1993487  1993487      287       6644        106              NaN
# 1993488  1993488      288       6644        114  species_decayed
# 1993489  1993489      289       6644         54              NaN
# 1993490  1993490      290       6644         87  species_decayed
# 1993491  1993491      291       6644         43  species_decayed
# 1993492  1993492      292       6644         22              NaN
# 1993493  1993493      293       6644         35  species_decayed
# 1993494  1993494      294       6644         13              NaN
# 1993495  1993495      295       6644         69              NaN
# 1993496  1993496      296       6644         78              NaN
# 1993497  1993497      297       6644         46  species_decayed
# 1993498  1993498      298       6644         74              NaN
# 1993499  1993499      299       6644         83  species_decayed
#
#          fsolve_error    eig_0_real  eig_0_imag    eig_1_real  eig_1_imag  \
# 0                   5  1.247208e+00    0.000000  2.561869e+00    0.000000
# 1                   1 -7.898492e-01    0.000000 -5.372419e+05    0.000000
# 2                   1 -2.869929e+04    0.000000 -1.347403e+00    0.000000
# 3                   1 -2.045571e+02    0.000000 -2.736584e-01    0.000000
# 4                   1 -5.320575e+06    0.000000 -3.438436e-01    0.000000
# 5                   5 -3.766379e+04    0.000000  6.887892e-01    0.000000
# 6                   5  2.521864e+00    0.000000  9.279987e-01    0.000000
# 7                   5  1.250300e+00    0.000000 -9.975415e-01    0.425756
# 8                   1           NaN    0.000000           NaN    0.000000
# 9                   1 -3.049621e-02    0.358858 -3.049621e-02   -0.358858
# 10                  1 -1.563357e+05    0.000000 -8.891986e-02    0.263900
# 11                  5  1.569126e+00    0.000000  1.568304e+00    0.000000
# 12                  5  1.441079e+00    0.000000 -1.261718e+00    0.000000
# 1993497             5  1.093996e+00    0.000000  2.616179e+00    0.000000
# 1993498             1 -6.110952e-02    0.294069 -6.110952e-02   -0.294069
# 1993499             5  6.993235e-01    0.000000  6.135325e-03    0.000000
#
#              ...        all_neg_eig  all_real_eig  all_zero_eig  Accepted  \
# 0            ...              False         False         False     False
# 1            ...               True         False         False     False
# 2            ...               True         False         False      True
# 3            ...               True          True         False     False
# 4            ...               True          True         False     False
# 5            ...              False          True         False     False
# 6            ...              False          True         False     False
# 7            ...              False         False         False     False
# 8            ...               True          True          True     False
# 9            ...               True         False         False     False
# 10           ...               True         False         False      True
# 11           ...              False         False         False     False
# 12           ...              False          True         False     False
# 13           ...              False         False         False     False
# 14           ...              False         False         False     False
# 15           ...              False         False         False     False
# 16           ...               True         False         False     False
# 17           ...              False          True         False     False
# 18           ...               True         False         False     False
# 19           ...               True         False         False      True
# 20           ...               True         False         False     False
# 21           ...              False         False         False     False
# 22           ...               True          True          True     False
# 23           ...              False         False         False     False
# 24           ...               True         False         False     False
# 25           ...              False          True         False     False
# 26           ...               True         False         False      True
# 27           ...               True         False         False     False
# 28           ...              False         False         False     False
# 29           ...               True         False         False      True
# ...          ...                ...           ...           ...       ...
# 1993470      ...              False         False         False     False
# 1993471      ...               True          True          True     False
# 1993472      ...               True         False         False     False
# 1993473      ...               True          True         False     False
# 1993474      ...               True         False         False      True
# 1993475      ...               True         False         False      True
# 1993476      ...              False         False         False     False
# 1993477      ...              False          True         False     False
# 1993478      ...              False         False         False     False
# 1993479      ...              False         False         False     False
# 1993480      ...              False          True         False     False
# 1993481      ...               True         False         False     False
# 1993482      ...               True         False         False      True
# 1993483      ...               True         False         False      True
# 1993484      ...               True         False         False     False
# 1993485      ...              False         False         False     False
# 1993486      ...              False         False         False     False
# 1993487      ...               True         False         False      True
# 1993488      ...              False         False         False     False
# 1993489      ...               True         False         False     False
# 1993490      ...              False         False         False     False
# 1993491      ...              False         False         False     False
# 1993492      ...               True         False         False      True
# 1993493      ...              False         False         False     False
# 1993494      ...               True         False         False      True
# 1993495      ...               True         False         False      True
# 1993496      ...               True         False         False      True
# 1993497      ...              False          True         False     False
# 1993498      ...               True         False         False      True
# 1993499      ...              False          True         False     False
#
#                     d1             d2             d3             d4  \
# 0        1.797693e+308  1.797693e+308  1.797693e+308  1.797693e+308
# 1        1.797693e+308  1.797693e+308  1.797693e+308  1.797693e+308
# 2         0.000000e+00   1.192093e-06   1.803211e+09   0.000000e+00
# 3        4.158591e-123  1.142648e-111  1.321177e-122   0.000000e+00
# 4        1.797693e+308  1.797693e+308  1.797693e+308  1.797693e+308
# 5         1.652850e+06   3.208747e+06   2.834563e+06   1.737671e+06
# 6        1.797693e+308  1.797693e+308  1.797693e+308  1.797693e+308
# 7        1.797693e+308  1.797693e+308  1.797693e+308  1.797693e+308
# 8        1.797693e+308  1.797693e+308  1.797693e+308  1.797693e+308
# 9        1.797693e+308  1.797693e+308  1.797693e+308  1.797693e+308
# 10        0.000000e+00   8.583069e-06   4.380790e+09   0.000000e+00
# 11       1.797693e+308  1.797693e+308  1.797693e+308  1.797693e+308
model_space_idx_list = model_space_report_df['model_idx'].values
acceptance_ratios = []

for row_idx, row in model_space_report_df.iterrows():
    acceptance_ratios.append(row['accepted_count'] / total_sims)
    

model_space_report_df['acceptance_ratio'] = acceptance_ratios
# Out:
# Index(['Unnamed: 0', 'model_idx', 'accepted_count', 'simulated_count',
#        'pos_loop_count', 'neg_loop_count', 'total_num_parts',
#        'loop_count_ratio'],
#       dtype='object')

# %% [markdown]
# ### Simulations summary

# %%
all_sims = joint_df
full_term_sims = joint_df.loc[joint_df['integ_error'].isnull()]
early_termination_sims = joint_df.loc[~joint_df['integ_error'].isnull()]

accepted_sims = joint_df.loc[joint_df['Accepted'] == True]
rejected_sims = joint_df.loc[joint_df['Accepted'] == False]

# Total number of simulations
print("Total sims: ", len(all_sims))
print("Num accepted: ", len(accepted_sims))
print("Num rejected: ", len(rejected_sims))
print("")
# Out:
# Total sims:  1993500
# Num accepted:  370561
# Num rejected:  1622939

# %% [markdown]
# ### Model posterior probability

# %%
style.use('seaborn-muted')

sub_model_report = model_space_report_df.loc[model_space_report_df['acceptance_ratio']]

model_space_report_df = model_space_report_df.sort_values(by='acceptance_ratio', ascending=False).reset_index(drop=True)

fig, ax = plt.subplots()
# Add error bars
sns.set_style("white")
sns.set_context("poster")
data_utils.generate_replicates_and_std(joint_df, model_space_report_df, 3)

ax.errorbar(model_space_report_df.index, 
            model_space_report_df['acceptance_ratio'], 
            yerr=model_space_report_df['stdev'], fmt=',', color='black', alpha=0.5,
            label=None, elinewidth=0.5)

sns.barplot(model_space_report_df.index, model_space_report_df.acceptance_ratio, 
                 data=model_space_report_df, alpha=1, ax=ax)

mean = np.mean(model_space_report_df['acceptance_ratio'].values)
ax.axhline(mean, ls='--', label='Mean', linewidth=1.0)

ax.set(xticklabels=[])
ax.set(ylabel='Acceptance Rate')
ax.set(xlabel='')
ax.set(xlim=(-1,None))
# ax.set(ylim=(-0,0.7))
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.legend()
ax.spines["left"].set_alpha(0.5)
ax.spines["bottom"].set_alpha(0.5)

plt.savefig(output_dir + "two_species_acceptance_rate.pdf", dpi=500)
# Out:
# /home/behzad/Documents/barnes_lab/cplusplus_software/speed_test/repressilator/cpp/venv/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   This is separate from the ipykernel package so we can avoid doing imports until
# Replicate:  0    Simulations:  996750
# Replicate:  1    Simulations:  996750

# %%
# print(model_space_report_df.columns)
# file = open("model_order.txt", "w") 
# for item in list(model_space_report_df['model_idx'].values):
#     file.write("%s\n" % item)
# file.close() 
for idx, row in model_space_report_df[['total_num_parts', 'model_idx', 'acceptance_ratio', 'stdev']].iterrows():
    print(row)
    print("")

print(model_space_report_df[['total_num_parts', 'model_idx', 'acceptance_ratio']])
# Out:
# total_num_parts      4.000000
# model_idx           93.000000
# acceptance_ratio     0.003995
# stdev                0.000011
# Name: 0, dtype: float64
#
# total_num_parts     5.000000
# model_idx           5.000000
# acceptance_ratio    0.003988
# stdev               0.000031
# Name: 1, dtype: float64
#
# total_num_parts      3.000000
# model_idx           44.000000
# acceptance_ratio     0.003712
# stdev                0.000006
# Name: 2, dtype: float64
#
# total_num_parts      4.000000
# model_idx           13.000000
# acceptance_ratio     0.003632
# stdev                0.000010
# Name: 3, dtype: float64
#
# total_num_parts      4.000000
# model_idx           67.000000
# acceptance_ratio     0.003543
# stdev                0.000009
# Name: 4, dtype: float64
#
# total_num_parts      6.000000
# model_idx           27.000000
# acceptance_ratio     0.003502
# stdev                0.000029
# Name: 5, dtype: float64
#
# total_num_parts      5.000000
# model_idx           73.000000
# acceptance_ratio     0.003457
# stdev                0.000021
# Name: 6, dtype: float64
#
# total_num_parts      5.000000
# model_idx           29.000000
# acceptance_ratio     0.003425
# stdev                0.000062
# Name: 7, dtype: float64
#
# total_num_parts      2.000000
# model_idx           79.000000
# acceptance_ratio     0.003403
# stdev                0.000042
# Name: 8, dtype: float64
#
# total_num_parts      4.000000
# model_idx           95.000000
# acceptance_ratio     0.003371
# stdev                0.000030
# Name: 9, dtype: float64
#
# total_num_parts       2.000000
# model_idx           123.000000
# acceptance_ratio      0.003350
# stdev                 0.000018
# Name: 10, dtype: float64
#
# total_num_parts       4.000000
# model_idx           121.000000
# acceptance_ratio      0.003337
# stdev                 0.000028
# Name: 11, dtype: float64
#
# total_num_parts       3.000000
# model_idx           119.000000
# acceptance_ratio      0.003327
# stdev                 0.000013
# Name: 12, dtype: float64
#
# total_num_parts      3.000000
# model_idx           77.000000
# acceptance_ratio     0.003325
# stdev                0.000038
# Name: 13, dtype: float64
#
# total_num_parts     5.000000
# model_idx           7.000000
# acceptance_ratio    0.003289
# stdev               0.000080
# Name: 14, dtype: float64
#
# total_num_parts       5.000000
# model_idx           101.000000
# acceptance_ratio      0.003282
# stdev                 0.000048
# Name: 15, dtype: float64
#
# total_num_parts      3.000000
# model_idx           69.000000
# acceptance_ratio     0.003248
# stdev                0.000006
# Name: 16, dtype: float64
#
# total_num_parts      5.000000
# model_idx           31.000000
# acceptance_ratio     0.003234
# stdev                0.000038
# Name: 17, dtype: float64
#
# total_num_parts      4.000000
# model_idx           75.000000
# acceptance_ratio     0.003224
# stdev                0.000007
# Name: 18, dtype: float64
#
# total_num_parts       4.000000
# model_idx           103.000000
# acceptance_ratio      0.003187
# stdev                 0.000023
# Name: 19, dtype: float64
#
# total_num_parts      3.000000
# model_idx           46.000000
# acceptance_ratio     0.003174
# stdev                0.000005
# Name: 20, dtype: float64
#
# total_num_parts      4.000000
# model_idx           33.000000
# acceptance_ratio     0.003169
# stdev                0.000036
# Name: 21, dtype: float64
#
# total_num_parts      4.000000
# model_idx           15.000000
# acceptance_ratio     0.003093
# stdev                0.000121
# Name: 22, dtype: float64
#
# total_num_parts       3.000000
# model_idx           107.000000
# acceptance_ratio      0.002900
# stdev                 0.000074
# Name: 23, dtype: float64
#
# total_num_parts       4.000000
# model_idx           111.000000
# acceptance_ratio      0.002848
# stdev                 0.000004
# Name: 24, dtype: float64
#
# total_num_parts      5.000000
# model_idx           89.000000
# acceptance_ratio     0.002818
# stdev                0.000003
# Name: 25, dtype: float64
#
# total_num_parts      4.000000
# model_idx           40.000000
# acceptance_ratio     0.002817
# stdev                0.000004
# Name: 26, dtype: float64
#
# total_num_parts     6.000000
# model_idx           1.000000
# acceptance_ratio    0.002806
# stdev               0.000046
# Name: 27, dtype: float64
#
# total_num_parts      5.000000
# model_idx           48.000000
# acceptance_ratio     0.002797
# stdev                0.000015
# Name: 28, dtype: float64
#
# total_num_parts     5.000000
# model_idx           9.000000
# acceptance_ratio    0.002608
# stdev               0.000028
# Name: 29, dtype: float64
#
# total_num_parts      4.000000
# model_idx           52.000000
# acceptance_ratio     0.002541
# stdev                0.000042
# Name: 30, dtype: float64
#
# total_num_parts      4.000000
# model_idx           92.000000
# acceptance_ratio     0.002286
# stdev                0.000016
# Name: 31, dtype: float64
#
# total_num_parts     5.000000
# model_idx           4.000000
# acceptance_ratio    0.002272
# stdev               0.000066
# Name: 32, dtype: float64
#
# total_num_parts     5.000000
# model_idx           6.000000
# acceptance_ratio    0.002189
# stdev               0.000006
# Name: 33, dtype: float64
#
# total_num_parts      5.000000
# model_idx           72.000000
# acceptance_ratio     0.002189
# stdev                0.000011
# Name: 34, dtype: float64
#
# total_num_parts      2.000000
# model_idx           78.000000
# acceptance_ratio     0.002149
# stdev                0.000042
# Name: 35, dtype: float64
#
# total_num_parts      4.000000
# model_idx           12.000000
# acceptance_ratio     0.002147
# stdev                0.000039
# Name: 36, dtype: float64
#
# total_num_parts      3.000000
# model_idx           43.000000
# acceptance_ratio     0.002143
# stdev                0.000014
# Name: 37, dtype: float64
#
# total_num_parts      4.000000
# model_idx           66.000000
# acceptance_ratio     0.002131
# stdev                0.000044
# Name: 38, dtype: float64
#
# total_num_parts       5.000000
# model_idx           100.000000
# acceptance_ratio      0.002118
# stdev                 0.000059
# Name: 39, dtype: float64
#
# total_num_parts     4.000000e+00
# model_idx           9.400000e+01
# acceptance_ratio    2.115375e-03
# stdev               5.016303e-07
# Name: 40, dtype: float64
#
# total_num_parts      3.000000
# model_idx           76.000000
# acceptance_ratio     0.002115
# stdev                0.000025
# Name: 41, dtype: float64
#
# total_num_parts       2.000000
# model_idx           122.000000
# acceptance_ratio      0.002114
# stdev                 0.000014
# Name: 42, dtype: float64
#
# total_num_parts       3.000000
# model_idx           118.000000
# acceptance_ratio      0.002113
# stdev                 0.000009
# Name: 43, dtype: float64
#
# total_num_parts      3.000000
# model_idx           45.000000
# acceptance_ratio     0.002100
# stdev                0.000018
# Name: 44, dtype: float64
#
# total_num_parts      6.000000
# model_idx           26.000000
# acceptance_ratio     0.002090
# stdev                0.000011
# Name: 45, dtype: float64
#
# total_num_parts      4.000000
# model_idx           14.000000
# acceptance_ratio     0.002083
# stdev                0.000017
# Name: 46, dtype: float64
#
# total_num_parts      5.000000
# model_idx           28.000000
# acceptance_ratio     0.002071
# stdev                0.000015
# Name: 47, dtype: float64
#
# total_num_parts       4.000000
# model_idx           120.000000
# acceptance_ratio      0.002055
# stdev                 0.000009
# Name: 48, dtype: float64
#
# total_num_parts       4.000000
# model_idx           102.000000
# acceptance_ratio      0.002052
# stdev                 0.000058
# Name: 49, dtype: float64
#
# total_num_parts       3.000000
# model_idx           109.000000
# acceptance_ratio      0.001992
# stdev                 0.000031
# Name: 50, dtype: float64
#
# total_num_parts      5.000000
# model_idx           30.000000
# acceptance_ratio     0.001982
# stdev                0.000035
# Name: 51, dtype: float64
#
# total_num_parts      4.000000
# model_idx           42.000000
# acceptance_ratio     0.001964
# stdev                0.000014
# Name: 52, dtype: float64
#
# total_num_parts      4.000000
# model_idx           74.000000
# acceptance_ratio     0.001955
# stdev                0.000059
# Name: 53, dtype: float64
#
# total_num_parts      5.000000
# model_idx           91.000000
# acceptance_ratio     0.001945
# stdev                0.000037
# Name: 54, dtype: float64
#
# total_num_parts      3.000000
# model_idx           68.000000
# acceptance_ratio     0.001942
# stdev                0.000017
# Name: 55, dtype: float64
#
# total_num_parts       4.000000
# model_idx           113.000000
# acceptance_ratio      0.001939
# stdev                 0.000019
# Name: 56, dtype: float64
#
# total_num_parts      4.000000
# model_idx           32.000000
# acceptance_ratio     0.001928
# stdev                0.000023
# Name: 57, dtype: float64
#
# total_num_parts      5.000000
# model_idx           50.000000
# acceptance_ratio     0.001916
# stdev                0.000026
# Name: 58, dtype: float64
#
# total_num_parts     6.000000
# model_idx           3.000000
# acceptance_ratio    0.001909
# stdev               0.000040
# Name: 59, dtype: float64
#
# total_num_parts      4.000000
# model_idx           54.000000
# acceptance_ratio     0.001851
# stdev                0.000025
# Name: 60, dtype: float64
#
# total_num_parts      5.000000
# model_idx           11.000000
# acceptance_ratio     0.001792
# stdev                0.000003
# Name: 61, dtype: float64
#
# total_num_parts      3.000000
# model_idx           64.000000
# acceptance_ratio     0.001293
# stdev                0.000003
# Name: 62, dtype: float64
#
# total_num_parts      3.000000
# model_idx           65.000000
# acceptance_ratio     0.001233
# stdev                0.000037
# Name: 63, dtype: float64
#
# total_num_parts       4.000000
# model_idx           112.000000
# acceptance_ratio      0.001001
# stdev                 0.000016
# Name: 64, dtype: float64
#
# total_num_parts       3.000000
# model_idx           108.000000
# acceptance_ratio      0.000999
# stdev                 0.000010
# Name: 65, dtype: float64
#
# total_num_parts     6.000000
# model_idx           2.000000
# acceptance_ratio    0.000995
# stdev               0.000020
# Name: 66, dtype: float64
#
# total_num_parts      4.000000
# model_idx           41.000000
# acceptance_ratio     0.000990
# stdev                0.000015
# Name: 67, dtype: float64
#
# total_num_parts      5.000000
# model_idx           10.000000
# acceptance_ratio     0.000952
# stdev                0.000010
# Name: 68, dtype: float64
#
# total_num_parts      4.000000
# model_idx           53.000000
# acceptance_ratio     0.000928
# stdev                0.000013
# Name: 69, dtype: float64
#
# total_num_parts      5.000000
# model_idx           90.000000
# acceptance_ratio     0.000926
# stdev                0.000002
# Name: 70, dtype: float64
#
# total_num_parts      5.000000
# model_idx           49.000000
# acceptance_ratio     0.000912
# stdev                0.000024
# Name: 71, dtype: float64
#
# total_num_parts       3.000000
# model_idx           106.000000
# acceptance_ratio      0.000901
# stdev                 0.000004
# Name: 72, dtype: float64
#
# total_num_parts     6.000000
# model_idx           0.000000
# acceptance_ratio    0.000890
# stdev               0.000012
# Name: 73, dtype: float64
#
# total_num_parts       4.000000
# model_idx           110.000000
# acceptance_ratio      0.000885
# stdev                 0.000016
# Name: 74, dtype: float64
#
# total_num_parts      5.000000
# model_idx           47.000000
# acceptance_ratio     0.000883
# stdev                0.000009
# Name: 75, dtype: float64
#
# total_num_parts      5.000000
# model_idx           88.000000
# acceptance_ratio     0.000856
# stdev                0.000014
# Name: 76, dtype: float64
#
# total_num_parts      4.000000
# model_idx           39.000000
# acceptance_ratio     0.000856
# stdev                0.000008
# Name: 77, dtype: float64
#
# total_num_parts      4.000000
# model_idx           51.000000
# acceptance_ratio     0.000812
# stdev                0.000025
# Name: 78, dtype: float64
#
# total_num_parts     5.000000
# model_idx           8.000000
# acceptance_ratio    0.000770
# stdev               0.000021
# Name: 79, dtype: float64
#
# total_num_parts      3.000000
# model_idx           58.000000
# acceptance_ratio     0.000616
# stdev                0.000022
# Name: 80, dtype: float64
#
# total_num_parts      4.000000
# model_idx           22.000000
# acceptance_ratio     0.000612
# stdev                0.000004
# Name: 81, dtype: float64
#
# total_num_parts      4.000000
# model_idx           23.000000
# acceptance_ratio     0.000607
# stdev                0.000033
# Name: 82, dtype: float64
#
# total_num_parts      3.000000
# model_idx           57.000000
# acceptance_ratio     0.000570
# stdev                0.000008
# Name: 83, dtype: float64
#
# total_num_parts      5.000000
# model_idx           18.000000
# acceptance_ratio     0.000556
# stdev                0.000006
# Name: 84, dtype: float64
#
# total_num_parts      4.000000
# model_idx           98.000000
# acceptance_ratio     0.000553
# stdev                0.000029
# Name: 85, dtype: float64
#
# total_num_parts      5.000000
# model_idx           19.000000
# acceptance_ratio     0.000549
# stdev                0.000015
# Name: 86, dtype: float64
#
# total_num_parts      4.000000
# model_idx           99.000000
# acceptance_ratio     0.000541
# stdev                0.000014
# Name: 87, dtype: float64
#
# total_num_parts       2.000000
# model_idx           126.000000
# acceptance_ratio      0.000028
# stdev                 0.000005
# Name: 88, dtype: float64
#
# total_num_parts       4.000000
# model_idx           125.000000
# acceptance_ratio      0.000027
# stdev                 0.000010
# Name: 89, dtype: float64
#
# total_num_parts       4.000000
# model_idx           105.000000
# acceptance_ratio      0.000026
# stdev                 0.000005
# Name: 90, dtype: float64
#
# total_num_parts     5.000000e+00
# model_idx           1.040000e+02
# acceptance_ratio    2.457988e-05
# stdev               5.016303e-07
# Name: 91, dtype: float64
#
# total_num_parts     3.000000e+00
# model_idx           1.240000e+02
# acceptance_ratio    1.755706e-05
# stdev               5.016303e-07
# Name: 92, dtype: float64
#
# total_num_parts       3.000000
# model_idx           114.000000
# acceptance_ratio      0.000003
# stdev                 0.000001
# Name: 93, dtype: float64
#
# total_num_parts      6.000000
# model_idx           35.000000
# acceptance_ratio     0.000003
# stdev                0.000000
# Name: 94, dtype: float64
#
# total_num_parts      5.000000
# model_idx           36.000000
# acceptance_ratio     0.000003
# stdev                0.000002
# Name: 95, dtype: float64
#
# total_num_parts     4.000000e+00
# model_idx           8.100000e+01
# acceptance_ratio    2.508151e-06
# stdev               5.016303e-07
# Name: 96, dtype: float64
#
# total_num_parts      5.000000
# model_idx           84.000000
# acceptance_ratio     0.000002
# stdev                0.000001
# Name: 97, dtype: float64
#
# total_num_parts      5.000000
# model_idx           37.000000
# acceptance_ratio     0.000002
# stdev                0.000000
# Name: 98, dtype: float64
#
# total_num_parts       3.000000
# model_idx           115.000000
# acceptance_ratio      0.000002
# stdev                 0.000000
# Name: 99, dtype: float64
#
# total_num_parts     5.000000e+00
# model_idx           9.600000e+01
# acceptance_ratio    1.504891e-06
# stdev               5.016303e-07
# Name: 100, dtype: float64
#
# total_num_parts      3.000000
# model_idx           82.000000
# acceptance_ratio     0.000001
# stdev                0.000001
# Name: 101, dtype: float64
#
# total_num_parts      4.000000
# model_idx           38.000000
# acceptance_ratio     0.000001
# stdev                0.000001
# Name: 102, dtype: float64
#
# total_num_parts       4.000000
# model_idx           116.000000
# acceptance_ratio      0.000001
# stdev                 0.000001
# Name: 103, dtype: float64
#
# total_num_parts      4.000000
# model_idx           85.000000
# acceptance_ratio     0.000001
# stdev                0.000001
# Name: 104, dtype: float64
#
# total_num_parts      4.0
# model_idx           70.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 105, dtype: float64
#
# total_num_parts      5.0
# model_idx           60.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 106, dtype: float64
#
# total_num_parts      4.0
# model_idx           61.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 107, dtype: float64
#
# total_num_parts      4.0
# model_idx           62.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 108, dtype: float64
#
# total_num_parts      4.0
# model_idx           83.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 109, dtype: float64
#
# total_num_parts      4.0
# model_idx           71.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 110, dtype: float64
#
# total_num_parts      3.0
# model_idx           80.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 111, dtype: float64
#
# total_num_parts      5.0
# model_idx           97.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 112, dtype: float64
#
# total_num_parts      4.0
# model_idx           56.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 113, dtype: float64
#
# total_num_parts      5.0
# model_idx           59.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 114, dtype: float64
#
# total_num_parts      6.0
# model_idx           16.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 115, dtype: float64
#
# total_num_parts      3.0
# model_idx           86.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 116, dtype: float64
#
# total_num_parts      5.0
# model_idx           34.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 117, dtype: float64
#
# total_num_parts      4.0
# model_idx           55.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 118, dtype: float64
#
# total_num_parts      5.0
# model_idx           21.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 119, dtype: float64
#
# total_num_parts      6.0
# model_idx           17.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 120, dtype: float64
#
# total_num_parts      5.0
# model_idx           20.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 121, dtype: float64
#
# total_num_parts      5.0
# model_idx           24.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 122, dtype: float64
#
# total_num_parts      5.0
# model_idx           25.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 123, dtype: float64
#
# total_num_parts      2.0
# model_idx           87.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 124, dtype: float64
#
# total_num_parts       4.0
# model_idx           117.0
# acceptance_ratio      0.0
# stdev                 0.0
# Name: 125, dtype: float64
#
# total_num_parts      4.0
# model_idx           63.0
# acceptance_ratio     0.0
# stdev                0.0
# Name: 126, dtype: float64
#
#      total_num_parts  model_idx  acceptance_ratio
# 0                4.0         93          0.003995
# 1                5.0          5          0.003988
# 2                3.0         44          0.003712
# 3                4.0         13          0.003632
# 4                4.0         67          0.003543
# 5                6.0         27          0.003502
# 6                5.0         73          0.003457
# 7                5.0         29          0.003425
# 8                2.0         79          0.003403
# 9                4.0         95          0.003371
# 10               2.0        123          0.003350
# 11               4.0        121          0.003337
# 12               3.0        119          0.003327
# 13               3.0         77          0.003325
# 14               5.0          7          0.003289
# 15               5.0        101          0.003282
# 16               3.0         69          0.003248
# 17               5.0         31          0.003234
# 18               4.0         75          0.003224
# 19               4.0        103          0.003187
# 20               3.0         46          0.003174
# 21               4.0         33          0.003169
# 22               4.0         15          0.003093
# 23               3.0        107          0.002900
# 24               4.0        111          0.002848
# 25               5.0         89          0.002818
# 26               4.0         40          0.002817
# 27               6.0          1          0.002806
# 28               5.0         48          0.002797
# 29               5.0          9          0.002608
# ..               ...        ...               ...
# 97               5.0         84          0.000002
# 98               5.0         37          0.000002
# 99               3.0        115          0.000002
# 100              5.0         96          0.000002
# 101              3.0         82          0.000001
# 102              4.0         38          0.000001
# 103              4.0        116          0.000001
# 104              4.0         85          0.000001
# 105              4.0         70          0.000000
# 106              5.0         60          0.000000
# 107              4.0         61          0.000000
# 108              4.0         62          0.000000
# 109              4.0         83          0.000000
# 110              4.0         71          0.000000
# 111              3.0         80          0.000000
# 112              5.0         97          0.000000
# 113              4.0         56          0.000000
# 114              5.0         59          0.000000
# 115              6.0         16          0.000000
# 116              3.0         86          0.000000
# 117              5.0         34          0.000000
# 118              4.0         55          0.000000
# 119              5.0         21          0.000000
# 120              6.0         17          0.000000
# 121              5.0         20          0.000000
# 122              5.0         24          0.000000
# 123              5.0         25          0.000000
# 124              2.0         87          0.000000
# 125              4.0        117          0.000000
# 126              4.0         63          0.000000
#
# [127 rows x 3 columns]

# %%
ax = sns.scatterplot(x='acceptance_ratio', y='loop_count_ratio', data=model_space_report_df)
ax.set(ylabel = 'Negative / positive loop score')
ax.set(xlabel = 'Bayes factor')
# Out:
# [Text(0.5, 0, 'Bayes factor')]

# %%
ax = sns.scatterplot(x='acceptance_ratio', y='neg_loop_count', data=model_space_report_df)
ax.set(ylabel = 'Negative loop score')
ax.set(xlabel = 'Bayes factor')
# Out:
# [Text(0.5, 0, 'Bayes factor')]

# %%
ax = sns.scatterplot(x='acceptance_ratio', y='pos_loop_count', data=model_space_report_df)
ax.set(ylabel = 'Positive loop score')
ax.set(xlabel = 'Bayes factor')
# Out:
# [Text(0.5, 0, 'Bayes factor')]
